# %% [markdown]
# # Linear Regression in R (AI-assisted)
#
# This notebook reads `regression_data.csv`, fits a simple linear regression model to predict **Salary** from **YearsExperience**, prints diagnostic statistics (including mean squared error), and saves an annotated scatter plot.

# %% [markdown]
# ## 1. Load libraries

# %%
# base R graphics (stats package provides lm())

# %% [markdown]
# ## 2. Read the CSV file

# %%
data <- read.csv("../regression_data.csv")
x_col <- "YearsExperience"
y_col <- "Salary"

print(head(data))
cat("\nNumber of rows:", nrow(data), "\n")
cat("Columns:", paste(colnames(data), collapse = ", "), "\n")
# Out:
#   YearsExperience Salary
# 1             1.1  39343
# 2             1.3  46205
# 3             1.5  37731
# 4             2.0  43525
# 5             2.2  39891
# 6             2.9  56642
# Number of rows: 10
# Columns: YearsExperience, Salary

# %% [markdown]
# ## 3. Fit a linear model and print diagnostics

# %%
formula <- as.formula(paste(y_col, "~", x_col))
model <- lm(formula, data = data)
summary_model <- summary(model)

y_actual <- data[[y_col]]
y_pred <- predict(model)

intercept <- coef(model)[1]
slope <- coef(model)[2]
r2 <- summary_model$r.squared
adj_r2 <- summary_model$adj.r.squared
p_value <- summary_model$coefficients[2, 4]
std_err <- summary_model$coefficients[2, 2]
mse <- mean((y_actual - y_pred)^2)
rmse <- sqrt(mse)
mae <- mean(abs(y_actual - y_pred))

cat(sprintf("Slope: %.2f\n", slope))
cat(sprintf("Intercept: %.2f\n", intercept))
cat(sprintf("Equation: %s = %.2f + %.2f * %s\n", y_col, intercept, slope, x_col))
cat(sprintf("R-squared: %.4f\n", r2))
cat(sprintf("Adjusted R-squared: %.4f\n", adj_r2))
cat(sprintf("p-value: %.6f\n", p_value))
cat(sprintf("Standard error: %.2f\n", std_err))
cat(sprintf("Mean Squared Error (MSE): %.2f\n", mse))
cat(sprintf("Root Mean Squared Error (RMSE): %.2f\n", rmse))
cat(sprintf("Mean Absolute Error (MAE): %.2f\n", mae))
# Out:
# Slope: 8285.29
# Intercept: 29203.52
# Equation: Salary = 29203.52 + 8285.29 * YearsExperience
# R-squared: 0.7852
# Adjusted R-squared: 0.7583
# p-value: 0.000641
# Standard error: 1532.33
# Mean Squared Error (MSE): 17523844.08
# Root Mean Squared Error (RMSE): 4186.15
# Mean Absolute Error (MAE): 3526.26

# %% [markdown]
# ## 4. Scatter plot with regression line and annotated statistics

# %%
x_vals <- data[[x_col]]
y_vals <- data[[y_col]]

png("linear_model_r_output.png", width = 800, height = 500, res = 150)
plot(
  x_vals,
  y_vals,
  pch = 19,
  col = "red",
  main = paste(y_col, "vs", x_col),
  xlab = x_col,
  ylab = y_col
)
abline(model, col = "blue", lwd = 2)
legend("bottomright", legend = c("Data points", "Regression line"), col = c("red", "blue"), pch = c(19, NA), lty = c(NA, 1), lwd = c(NA, 2))
annotation <- sprintf(
  "y = %.2fx + %.2f\nR² = %.2f\nMSE = %.2f",
  slope, intercept, r2, mse
)
text(
  x = min(x_vals),
  y = max(y_vals),
  labels = annotation,
  adj = c(0, 1),
  cex = 0.9
)
dev.off()
cat("Saved plot: linear_model_r_output.png\n")
# Out:
# pdf
#   2
# Saved plot: linear_model_r_output.png
